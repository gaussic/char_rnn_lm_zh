# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

import time
import math

use_cuda = torch.cuda.is_available()

# %%
class LMConfiguration(object):
    rnn_type = 'LSTM'
    vocab_size = 5000
    embedding_dim = 200
    hidden_dim = 200
    n_layers = 2
    dropout = 0.5
    tied_weights = True
    
    max_len = 30
    learning_rate = 20

# %%
class RNNModel(nn.Module):
    def __init__(self, config):
        super(RNNModel, self).__init__()
        
        dropout = config.dropout
        vocab_size = config.vocab_size
        embedding_dim = config.embedding_dim
        tied_weights = config.tied_weights
        
        self.hidden_dim = hidden_dim = config.hidden_dim
        self.rnn_type = rnn_type = config.rnn_type
        self.n_layers = n_layers = config.n_layers
        
        self.drop = nn.Dropout(dropout)
        self.encoder = nn.Embedding(vocab_size, embedding_dim)
        
        if rnn_type in ['LSTM', 'GRU']:
            self.rnn = getattr(nn, rnn_type)(embedding_dim, hidden_dim, n_layers, dropout=dropout)
        else:
            raise ValueError("""'rnn_type' error, use ['LSTM', 'GRU']""")
            
        self.decoder = nn.Linear(hidden_dim, vocab_size)
        
        if tied_weights:
            if embedding_dim != hidden_dim:
                raise ValueError('When using the tied falg, embedding_dim must be equal to hidden_dim')
            self.decoder.weight = self.encoder.weight   
        
        self.init_weights()
        
    def forward(self, inputs, hidden):
        embedded = self.drop(self.encoder(inputs))
        output, hidden = self.rnn(embedded, hidden)
        output = self.drop(output)
        decoded = self.decoder(output.view(output.size(0) * output.size(1), output.size(2)))
        return decoded.view(output.size(0), output.size(1), decoded.size(1)), hidden
        
            
    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.fill_(0)
        
    def init_hidden(self, bsz):
        weight = next(self.parameters()).data
        if self.rnn_type == 'LSTM':
            # LSTM h0, c0
            return (Variable(weight.new(self.n_layers, bsz, self.hidden_dim).zero_()),
                    Variable(weight.new(self.n_layers, bsz, self.hidden_dim).zero_()))
        else:
            # GRU h0
            return Variable(weight.new(self.n_layers, bsz, self.hidden_dim).zero_())

# %%
def batchify(data, bsz):
    # Work out how cleanly we can divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    if use_cuda:
        data = data.cuda()
    return data

# %%
from data_zh import *

# %%
corpus = Corpus('data/sanguoyanyi.txt')

# %%
print(len(corpus.dictionary))
print(len(corpus.train))
# Out:
# 4003
# 606572

# %%
train_batch_size = 20
config = LMConfiguration()
train_data = batchify(corpus.train, train_batch_size)

# %%
print(train_data.size())
# Out:
# torch.Size([30328, 20])

# %%
config.vocab_size = len(corpus.dictionary)
model = RNNModel(config)

# %%
if use_cuda:
    model.cuda()

# %%
criterion = nn.CrossEntropyLoss()

# %%
def get_batch(source, i, evaluation=False):
    seq_len = min(config.max_len, len(source) - 1 - i)
    data = Variable(source[i:i+seq_len], volatile=evaluation)
    target = Variable(source[i+1:i+1+seq_len].view(-1))
    return data, target

# %%
def repackage_hidden(h):
    if type(h) == Variable:
        return Variable(h.data)
    else:
        return tuple(repackage_hidden(v) for v in h)

# %%
def train():
    model.train()
    total_loss = 0
    start_time = time.time()
    hidden = model.init_hidden(train_batch_size)
    for batch, i in enumerate(range(0, train_data.size(0) - 1, config.max_len)):
        data, targets = get_batch(train_data, i)
        
        hidden = repackage_hidden(hidden)
        model.zero_grad()
        output, hidden = model(data, hidden)
        loss = criterion(output.view(-1, config.vocab_size), targets)
        loss.backward()
        
        torch.nn.utils.clip_grad_norm(model.parameters(), 0.25)
        
        for p in model.parameters():
            p.data.add_(-lr, p.grad.data)
        
        total_loss += loss.data
        
        print_per_batch = 200
        if batch % 200 == 0 and batch > 0:
            cur_loss = total_loss[0] / print_per_batch
            elapsed = time.time() - start_time
            msg = '| epoch {:3d} | {:5d}/{:5d} batches | lr {:02.2f} | ms/batch {:5.2f} | loss {:5.2f} | ppl {:8.2f} |'
            print(msg.format(epoch, batch, len(train_data) // config.max_len, lr, 
                     elapsed * 1000 / print_per_batch, cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()
            
        if batch % 1000 == 0 and batch > 0:
            word_list = generate()
            print(''.join(word_list))

# %%
def generate(word_len=100):
    inputs = Variable(torch.rand(1, 1).mul(config.vocab_size).long(), volatile=True)
    if use_cuda:
        inputs.data = inputs.data.cuda()
    hidden = model.init_hidden(1)
    word_list = []
    for i in range(word_len):
        output, hidden = model(inputs, hidden)
        word_weights = output.squeeze().data.div(1).exp().cpu()
        word_idx = torch.multinomial(word_weights, 1)[0]
        inputs.data.fill_(word_idx)
        word = corpus.dictionary.idx2word[word_idx]
        word_list.append(word)
    return word_list

# %%
lr = config.learning_rate
for epoch in range(1, 100):
    train()
    lr /= 4
# Out:
# | epoch   1 |   200/ 1010 batches | lr 20.00 | ms/batch  8.92 | loss  6.50 | ppl   662.86 |
# | epoch   1 |   400/ 1010 batches | lr 20.00 | ms/batch  7.99 | loss  5.78 | ppl   325.34 |
# | epoch   1 |   600/ 1010 batches | lr 20.00 | ms/batch  7.97 | loss  5.46 | ppl   234.28 |
# | epoch   1 |   800/ 1010 batches | lr 20.00 | ms/batch  7.97 | loss  5.29 | ppl   198.36 |
# | epoch   1 |  1000/ 1010 batches | lr 20.00 | ms/batch  7.96 | loss  5.17 | ppl   176.40 |
# 反略过，从子安八将，非为张伺虑报之。”皓泣笑曰：“幔忘不马，将封炳坂一愿；免大掠卧钱天中。三将官蛛太，共归上锯，死襄国舞兆，我海蔽卫之之之晏。”<eos>陆将，宫马从舍，随后相出，又将一千军，船中大寨”，一怒
# | epoch   2 |   200/ 1010 batches | lr 5.00 | ms/batch  8.02 | loss  5.12 | ppl   168.05 |
# | epoch   2 |   400/ 1010 batches | lr 5.00 | ms/batch  8.00 | loss  5.03 | ppl   152.85 |
# | epoch   2 |   600/ 1010 batches | lr 5.00 | ms/batch  7.97 | loss  4.93 | ppl   138.63 |
# | epoch   2 |   800/ 1010 batches | lr 5.00 | ms/batch  7.96 | loss  4.90 | ppl   134.17 |
# | epoch   2 |  1000/ 1010 batches | lr 5.00 | ms/batch  8.07 | loss  4.87 | ppl   130.83 |
# 曰：“关公去忙何议？”操视之，于南子师逼，恐称孔明，赍前入来。于是朱泰、御一人釿，落四个击。却说赵云芦斐斧开寨后与王孙渊师迎了，入城年中，字扶岸余陂；“要退人师。孟获回命，知截败一里，魏兵不言部军救主
# | epoch   3 |   200/ 1010 batches | lr 1.25 | ms/batch  8.01 | loss  4.96 | ppl   142.01 |
# | epoch   3 |   400/ 1010 batches | lr 1.25 | ms/batch  7.98 | loss  4.90 | ppl   134.88 |
# | epoch   3 |   600/ 1010 batches | lr 1.25 | ms/batch  7.99 | loss  4.82 | ppl   124.19 |
# | epoch   3 |   800/ 1010 batches | lr 1.25 | ms/batch  7.99 | loss  4.81 | ppl   122.49 |
# | epoch   3 |  1000/ 1010 batches | lr 1.25 | ms/batch  8.00 | loss  4.79 | ppl   120.69 |
# ，城中手以有三十锐，又牁藏满郯；尚杀以先主。遵曰：“眩肚几年皎，以将马之乘粮冥下？今有大事。其通不汉。吾负兵来，绑得跨拘，何罪算无？”承曰：“吾可遣后人主假将吴德多，不可疑言，放必先行。操登间关公子冬
# | epoch   4 |   200/ 1010 batches | lr 0.31 | ms/batch  8.03 | loss  4.91 | ppl   134.97 |
# | epoch   4 |   400/ 1010 batches | lr 0.31 | ms/batch  8.00 | loss  4.86 | ppl   129.55 |
# | epoch   4 |   600/ 1010 batches | lr 0.31 | ms/batch  7.99 | loss  4.79 | ppl   119.80 |
# | epoch   4 |   800/ 1010 batches | lr 0.31 | ms/batch  8.28 | loss  4.78 | ppl   119.02 |
# | epoch   4 |  1000/ 1010 batches | lr 0.31 | ms/batch  8.24 | loss  4.77 | ppl   117.90 |
# 驿凉，倘操亦月埃祖道；非吕布与杨福真位。未欲兄书水日与操、王法等，被孔明不以父董帝相欲，通战无忘。时至谷外又轻见沙口之意，山门问炮搠。看过火穿已璧，告眼人马，人要劳身之，面声打地。乘不知。诸王人有太
# | epoch   5 |   200/ 1010 batches | lr 0.08 | ms/batch  8.11 | loss  4.89 | ppl   133.15 |
# | epoch   5 |   400/ 1010 batches | lr 0.08 | ms/batch  8.06 | loss  4.85 | ppl   128.30 |
# | epoch   5 |   600/ 1010 batches | lr 0.08 | ms/batch  8.01 | loss  4.78 | ppl   118.95 |
# | epoch   5 |   800/ 1010 batches | lr 0.08 | ms/batch  8.02 | loss  4.77 | ppl   118.23 |
# | epoch   5 |  1000/ 1010 batches | lr 0.08 | ms/batch  8.02 | loss  4.76 | ppl   117.27 |
# 年旨，以变大心，稍扰三队。乌氏于胁、司马昭，且久敢杀之言。玄德等自乘身，可行其去。谧闭壁，教书至。尔梳于地外，手祭策斧，亦目与天相妻，夏子亮为，令魏仁征东吴王夫人庵断。吕布抄见知曹操，请他弟蜀卫官马投
# | epoch   6 |   200/ 1010 batches | lr 0.02 | ms/batch  8.05 | loss  4.89 | ppl   132.67 |
# | epoch   6 |   400/ 1010 batches | lr 0.02 | ms/batch  8.01 | loss  4.85 | ppl   127.93 |
# | epoch   6 |   600/ 1010 batches | lr 0.02 | ms/batch  8.24 | loss  4.78 | ppl   118.84 |
# | epoch   6 |   800/ 1010 batches | lr 0.02 | ms/batch  8.02 | loss  4.77 | ppl   117.57 |
# | epoch   6 |  1000/ 1010 batches | lr 0.02 | ms/batch  8.02 | loss  4.76 | ppl   116.61 |
# 议。先日是诏曰：“来又得图妾天褚，汝等请答将，瑾极过监小家献之祸矣。”其曰：“先督安计？”孙乾饮不容彧，急往忽视者言至，令即择军进；皆待故者。瓒斩罪大骂：“今日说二事，昔不用降，郸欲能进；非自成兵。”
# | epoch   7 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.77 |
# | epoch   7 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   127.90 |
# | epoch   7 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   118.22 |
# | epoch   7 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.74 |
# | epoch   7 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   116.74 |
# ”肃鞍听。后人曰：“镇冀年既亡之战，一处之口，东洪无荡，姓钺，窃中君，东王德业，前得有之；九消养气，共无人盛？<eos>吾夜言云长到，口当将中，恨天负之疑，不可投。彼至九里十六年之道，哨下可在屯兵，早赐前。”
# | epoch   8 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.89 | ppl   132.60 |
# | epoch   8 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.85 | ppl   127.93 |
# | epoch   8 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.61 |
# | epoch   8 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   118.15 |
# | epoch   8 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   116.79 |
# 失春，回扑公乃军士，大喜大而，设于舍卫后，汉中刘操大叫，兴征。”瑜曰：“城人必回幅，径至山谷到。犯我得严义相敌，乃伴九夫将植，结国大功，万督篙英阳，必受诚逆。”原报孔明大喜曰：“昔日同请出东郡，因在帝
# | epoch   9 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.89 | ppl   132.34 |
# | epoch   9 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.34 |
# | epoch   9 |   600/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.78 | ppl   118.73 |
# | epoch   9 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.63 |
# | epoch   9 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   117.05 |
# 。双邦之中，料广阳数十万，蜀终攻大将。”言讫，来见乡镇言归，布喝叱曰：“咛盛向有汝，必父无罪！”松谓松曰：“吾曹操之甚何？”众人曰：“此为引出居平，太自两三家之多息，当艚拷欺辂。”众皆足掩及。髦答曰：
# | epoch  10 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.89 | ppl   132.66 |
# | epoch  10 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.86 | ppl   128.39 |
# | epoch  10 |   600/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.78 | ppl   118.73 |
# | epoch  10 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.91 |
# | epoch  10 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   117.02 |
# 拜遣辽侯两人相觉。乃大酒。诸将杨明去了云长腹卒，军皆然接，便李化收兵迎已，瑜不信。操急顾张肃曰：“士人何因凄粮安迟？”至来说曰：“非若得哉！”术曰：“汝等听三一十余余百九侯，不动通东尽，当亦吕布内耶！
# | epoch  11 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.89 | ppl   132.38 |
# | epoch  11 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.85 | ppl   128.36 |
# | epoch  11 |   600/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.78 | ppl   118.65 |
# | epoch  11 |   800/ 1010 batches | lr 0.00 | ms/batch  8.16 | loss  4.77 | ppl   117.54 |
# | epoch  11 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.37 | loss  4.76 | ppl   117.09 |
# 、蛮侯之城壮。如令来取长，乃反命所进。卯势三泪小下大邵，两御践开，百一箭装不搜；青夜平勇，数人恨到阙角。飞开拍马声冲。逢重去之，羲豹官公喟倾、累杀后，乃孟景，酒将军嘱曰：“之兄欺孙策廷族人，不如臣几，
# | epoch  12 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.57 |
# | epoch  12 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.37 |
# | epoch  12 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.66 |
# | epoch  12 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.98 |
# | epoch  12 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   116.85 |
# 守谷口，囷箭中乔将，宣愧其重也。”侍中宫筑劝曰：“汝不胜诺。”绍曰：“馒说献天罪。”耆曰：“吉主士，佗以当之，遍上热受。”时人有诗赞曰：“你晚休已惧之，不识一女柴观逆怒。綝却投了江河习而过。忽听伞挥在
# | epoch  13 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.46 |
# | epoch  13 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.86 | ppl   128.49 |
# | epoch  13 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.62 |
# | epoch  13 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.56 |
# | epoch  13 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   116.59 |
# 场气结裂！魏延八将伐长的神住阳，武安扼运人诏孙遂将军栅，大慈遣成正行。髦再言曰：“我料万手皆并把老谶。”维叱曰：“不肯问公烹礼险雄，可以平备物。权兼绍，家必起绍哉。”即教去见。两军二人率兵，背后曹操往
# | epoch  14 |   200/ 1010 batches | lr 0.00 | ms/batch  8.03 | loss  4.89 | ppl   132.66 |
# | epoch  14 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.85 | ppl   127.83 |
# | epoch  14 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   118.50 |
# | epoch  14 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.70 |
# | epoch  14 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   117.04 |
# 矣。僮干向城斗下，挂的初中铁出，过了城立高落左右，使人皆让告有曹策。曹仁拜问，皆为引小军来战。<eos>表自排殉，一鼓炮衣舸而箭，检首一城。正将刺流妻勇，克顷降走，又听战前时马。<eos>却说太督贤遣人全飞、孙众出视
# | epoch  15 |   200/ 1010 batches | lr 0.00 | ms/batch  8.03 | loss  4.89 | ppl   132.69 |
# | epoch  15 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.85 | ppl   128.16 |
# | epoch  15 |   600/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.78 | ppl   118.55 |
# | epoch  15 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.70 |
# | epoch  15 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   117.00 |
# 。此间垢送横剑遭江奸箭池击马！”孔明曰：“臣龙吾有本人，以自唾于斩仇。我当上背师聚下，如去慢璋来取吾，”逊即暗妙间曰：“人已兄也。”且说吕艾用军请大贩折了，长称名承，虎减咸子，吉主子玄，家臣重兽士池，
# | epoch  16 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.55 |
# | epoch  16 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.85 | ppl   128.18 |
# | epoch  16 |   600/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.77 | ppl   118.48 |
# | epoch  16 |   800/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.77 | ppl   117.76 |
# | epoch  16 |  1000/ 1010 batches | lr 0.00 | ms/batch  7.99 | loss  4.76 | ppl   117.04 |
# 马，进战出路。又行马，冒观数山：催军赶在南北休图之，正是与刘傕：兼鞍河中十余里，以草压血仓雄，惶扶自养者：闻蜀将谢了。妇者：<eos>时自祭，绿速船台，被有以天子手烂粲之；自反德向岁之小将弩威。今事若相卿所及
# | epoch  17 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.89 | ppl   132.60 |
# | epoch  17 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   127.86 |
# | epoch  17 |   600/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.78 | ppl   118.77 |
# | epoch  17 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.53 |
# | epoch  17 |  1000/ 1010 batches | lr 0.00 | ms/batch  7.99 | loss  4.76 | ppl   117.12 |
# 命书，“驴显天下，某见濮安相奏。吾见敌有大事！”玄德已应，方喜，具谓左右曰：“汝今得节，恨焉如何？”大喜，邀拨缺闭在川。玄德乃傍晌豺酋；宣黄阳裨欣，马尚咬季，以先子抚添，忠介义如降。操曰：“城下写报子
# | epoch  18 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.88 | ppl   132.26 |
# | epoch  18 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.86 | ppl   128.56 |
# | epoch  18 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.57 |
# | epoch  18 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.62 |
# | epoch  18 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   117.19 |
# 军服生，以为出都。又面分布灵十人相整，看成两川。今却看步来宽益，下七万在剧竹，并自干槽入头；”士将放剑袍坂，失拾土头，索平妄带寐杂，书留父安劫江川，何看邀先魏进商锋。”肃曰：“汝等何重逆？明和他。今为
# | epoch  19 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.72 |
# | epoch  19 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.85 | ppl   128.05 |
# | epoch  19 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   118.32 |
# | epoch  19 |   800/ 1010 batches | lr 0.00 | ms/batch  8.09 | loss  4.77 | ppl   117.44 |
# | epoch  19 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.39 |
# 起罪之，必受奇恙。若故不致前登。”即飞马报出丞相此，度哮古多。綝即命，鹅多樊路之士。<eos>望是净，正有人送廷原有袁权，读付汉师。<eos>二沛皆在城。二人拜说：“为此褒才胡家诸之道事。来嫉在帐中，死迟法术，肩涂称
# | epoch  20 |   200/ 1010 batches | lr 0.00 | ms/batch  8.10 | loss  4.89 | ppl   132.30 |
# | epoch  20 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.27 |
# | epoch  20 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.68 |
# | epoch  20 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.59 |
# | epoch  20 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   117.22 |
# 、赤语鸠望关公，日中级列一行其府，疆豕具定此母，名雷狡，安所贤癖。德请遣辱权，昏于周表；貌罚霞晋到，谦酗魂所。乃不得落之耳。若有兼计；引兵前托杀和，只得望营。关公混刀前来，坐宫回来。览毕，令一将之计，
# | epoch  21 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.88 | ppl   132.26 |
# | epoch  21 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.18 |
# | epoch  21 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.61 |
# | epoch  21 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.40 |
# | epoch  21 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   116.83 |
# 曲粮袍，事铠不珪。东慈不能忧何？此方受恨，取请汝始胜关。身。”朗亦叹曰：“汝与吾等副事，督来出荆州！何故欺我？”乃大喜，乃司马昭往曹洪。<eos>其子不能去。圣君好请先屯公，懿奏玄德之迄；曹操正至鱼油之液，痛
# | epoch  22 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.59 |
# | epoch  22 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   127.99 |
# | epoch  22 |   600/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.78 | ppl   118.68 |
# | epoch  22 |   800/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.77 | ppl   117.63 |
# | epoch  22 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.35 |
# 之上，开谷阿在园。难飞忘有筛繁。吾兵性差者象进兵喜，迩作丧面，如文辂受之。睿曰：“吾大心，汝今当心溪戏，无为足既。”令所智溢不益州。董朗性教刘氏等先生，方言平枪拜死，教东自四姓洒鞍：受虎忠。<eos>张鲁在驰
# | epoch  23 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.80 |
# | epoch  23 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.85 | ppl   128.08 |
# | epoch  23 |   600/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.78 | ppl   118.66 |
# | epoch  23 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.71 |
# | epoch  23 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   117.18 |
# 郦，艨伏张苞，祷珠统围眷。鲜聚攸苦将，佑工谴粮，则鼓犯之：谭杨登，重据跪息，不敢败敌。蔡严同称瞻高。粥散视之，又有青书玷史锐楯，孔明逆愿相劝，德死之凭不居温士。乐极驰辑，一作二言也。忽闻公将围胜，又令
# | epoch  24 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.89 | ppl   132.41 |
# | epoch  24 |   400/ 1010 batches | lr 0.00 | ms/batch  7.99 | loss  4.86 | ppl   128.59 |
# | epoch  24 |   600/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.78 | ppl   119.18 |
# | epoch  24 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.80 |
# | epoch  24 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   116.88 |
# 始，具就偶进。随了人把王纽出，令时雒桥薄中五千。王拜起准凯，于米帜自随，与军马、左右守兆。谓曰：“此昔每主军自取魏延，可敢死兵。又善次军已失。参兵必来报何。”<eos>却说董操陈桓等立祭，陈且奏曰：“另妆江东
# | epoch  25 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.86 |
# | epoch  25 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   127.85 |
# | epoch  25 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.76 |
# | epoch  25 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.98 |
# | epoch  25 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   116.75 |
# <eos>近室外举，运新冠藏，直得山上之地，建阵骑驰一面军鱼马。于是周卫于内下，两十千猛出牒重。正推取寇间，拜喝斩知。玄后有诗曰：“备是此拜我！<eos>表擒宫师报知葛綝。岩奉诱此观。”荼儒曰：“恋良不智，孤未好不哭
# | epoch  26 |   200/ 1010 batches | lr 0.00 | ms/batch  8.07 | loss  4.89 | ppl   132.80 |
# | epoch  26 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.05 |
# | epoch  26 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.51 |
# | epoch  26 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.34 |
# | epoch  26 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   117.25 |
# 子人以甫；止恐其语，未必敢明之意，恐不容内托，易今奉缺。段头伍指，免内黍答；谋国害，志。要死壮，得不回灰。”事故曰：“刘备老弟勿以了，细与潼其。”却看武蛮武奏，欲说你献袁年为建君命级已允。缓与府超默然
# | epoch  27 |   200/ 1010 batches | lr 0.00 | ms/batch  8.07 | loss  4.88 | ppl   132.29 |
# | epoch  27 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.85 | ppl   128.05 |
# | epoch  27 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.94 |
# | epoch  27 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.56 |
# | epoch  27 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.59 |
# 昭，船江御雷，极绳于大天，一海可投矣。”<eos>瑜笑曰：“昨家何我来所室？。如心壮绳为吾也。”孙权听罢，辛竺、申会可排在庞统，孙貂不能图此止，誓哥寻绝。忽被分有一驱韦甄也。正遇将，遂从城处汉陵者歇于淑玉。曹
# | epoch  28 |   200/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.89 | ppl   132.90 |
# | epoch  28 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.86 | ppl   128.78 |
# | epoch  28 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.75 |
# | epoch  28 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.92 |
# | epoch  28 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   116.71 |
# 虹招好也。袁表驾引兵而归赵云，从；安特急败外事：但差军领兵当号，便往耶？不知大事皆不夺亨。主褚弃东南安，以伏江郡二路。”形风披珠射住，指顾三右门。谭失首甚语。布曰：“国诸相出；必与何国在戍逊之后？”兴
# | epoch  29 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.31 |
# | epoch  29 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.85 | ppl   127.85 |
# | epoch  29 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   118.41 |
# | epoch  29 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.75 |
# | epoch  29 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   117.03 |
# 腹。”正唤：“叙何辞？”<eos>正言聪舌梦通莫，关逊窃渡火停，只旋蝉酒朽，遂望一上下诚言曰：“愿自门陵对天凭我之不矣！以无听德之易。”蔽曰：“兴童主陛番册得刘班、糜岱收兵至，只复一八万远史靴，二嫂请弟出寨。
# | epoch  30 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.89 | ppl   132.97 |
# | epoch  30 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.23 |
# | epoch  30 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.77 |
# | epoch  30 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.82 |
# | epoch  30 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   116.56 |
# 引数篇，送自折数江产为兵人。主公心胜之。玄德急听知说！”人曰：“不想俸山上，翎独千余晤，孤争不能遂投。”众皆言曰：“公乃足辞知何斩往？”杀王—太史诸葛，程暹与川瑁官还曹操后庙琬闭驾，恐智说其后玄德。怜
# | epoch  31 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.80 |
# | epoch  31 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.85 | ppl   128.26 |
# | epoch  31 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.54 |
# | epoch  31 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.68 |
# | epoch  31 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   116.90 |
# 炫。成公、赵颜城东南并腴西太安，作泪坐威，起卒姓衣，物茔大震，诛闻江阳，更是赞来曰：“此不其住，共不如好耳，愿当引一万军，来有汉前；乃吞罪之地矣！”命大怒送于内，乃申权笑于张匹。言讫毕而时，悌曰：“吾
# | epoch  32 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.39 |
# | epoch  32 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.86 | ppl   128.73 |
# | epoch  32 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.77 |
# | epoch  32 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.57 |
# | epoch  32 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   116.79 |
# 可神之其暗扇；璆敬书，油火立啸阳。今抹无甲应。<eos>但伤长后来身，力回江门，如来为粮水，若如何如何？”松曰：“军离太守鞦霆，在城中居长兖州，如何不迟！”云哭笑回见，孔明问之。允曰：“缓此百已，忽见汝怕。众
# | epoch  33 |   200/ 1010 batches | lr 0.00 | ms/batch  8.07 | loss  4.89 | ppl   132.54 |
# | epoch  33 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.86 | ppl   128.61 |
# | epoch  33 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.75 |
# | epoch  33 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.80 |
# | epoch  33 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   116.79 |
# 此，别旧谋王，叱玄德、吕达有妻罪，遣越白在豺口来，最酒起路，将。汜直回立时门苏，再拨将军杀往一抡：睿闻剑以戈辈，力如尘光，涂下数里。张良拍马回军，乘马回城是这余里。<eos>操将人，且约后大惊。司马懿每后看探
# | epoch  34 |   200/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.88 | ppl   132.26 |
# | epoch  34 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.21 |
# | epoch  34 |   600/ 1010 batches | lr 0.00 | ms/batch  8.08 | loss  4.78 | ppl   118.70 |
# | epoch  34 |   800/ 1010 batches | lr 0.00 | ms/batch  8.07 | loss  4.77 | ppl   117.77 |
# | epoch  34 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   116.81 |
# ，人大惊整义。真：“你留诈竺大家若听奸色！”<eos>叱刀冲赴良事，来死兵退，被献关官推断。枳急叱曰：“若急知杨达且破？其意有要图之：安初灵邰，荆州误父与人之策。”操付公念，计辞诸位。郭竺曰：“将使侯登，而敢
# | epoch  35 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.57 |
# | epoch  35 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.33 |
# | epoch  35 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.79 |
# | epoch  35 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.70 |
# | epoch  35 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   116.81 |
# 首是之。今得将军张郎，求敌下师，却如四枪五处之首也。”<eos>飞曰：“只然心事若来。糜鲁不肯怀用，慈称不惧。山内奉天，姓智，不足轻动。”遂遣二人回成史耽，下二十人杀劳；令玄德亲往报知否。韩苞曰：“外主未敢动
# | epoch  36 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.89 | ppl   133.08 |
# | epoch  36 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.85 | ppl   128.36 |
# | epoch  36 |   600/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.78 | ppl   118.63 |
# | epoch  36 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.59 |
# | epoch  36 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   116.91 |
# 于凑门，建侯、入马，令范骑守宥，何子大笑诸葛尚驽庇方守。相王刘淮义密大推，曰：‘我愿亲安主功，若何？”后泉曰：“远欲退蜀，双定之众之贼，不恤吾醒。遂是洛阳？”斗有姓心，先当议语。荀良从其言。玄德曰：
# | epoch  37 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.45 |
# | epoch  37 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.85 | ppl   128.12 |
# | epoch  37 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.54 |
# | epoch  37 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.81 |
# | epoch  37 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   116.85 |
# 然。班士有辛修立政，使曹坚而出之策，欣能搦间，简布家等，早然事何相语！<eos>未见之间，驴外有何勇也。自人后诗曰：“诚不益母守恩，必人答之。今公真昨防董皇叔，封之允。今害敌族母学去，恐乘洛相耽，商议曹操，有
# | epoch  38 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.89 | ppl   132.92 |
# | epoch  38 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.86 | ppl   128.39 |
# | epoch  38 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.77 |
# | epoch  38 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.88 |
# | epoch  38 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   116.94 |
# 立之；液通无功，家满户余心，玄德能有奉海之贤；切纳耳？未知我遗相岛，岂以言？”<eos>正是：大如义求终六人，果调掌书与扶缺理罪此遣。”帝厉声曰：“父弟要整憩不十家，俺碎莱阳之：涕祖拥图，期虽陛分。亲守依酒客
# | epoch  39 |   200/ 1010 batches | lr 0.00 | ms/batch  8.07 | loss  4.89 | ppl   132.63 |
# | epoch  39 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.85 | ppl   128.08 |
# | epoch  39 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.78 |
# | epoch  39 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.84 |
# | epoch  39 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   117.21 |
# 无。鲁家挺枪手令，立于城角，搦坐入马而出，立幡受食。<eos>孔明曰：“是过命，亦走赏取脱？”张嶷令一将而入。程舒到四水，兵中将已止。铜怒只再一视；浔散玄德将喃向来，草下车上鼓立于人，大叫：“见刘表、傅、张淮
# | epoch  40 |   200/ 1010 batches | lr 0.00 | ms/batch  8.07 | loss  4.89 | ppl   132.96 |
# | epoch  40 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.85 | ppl   128.29 |
# | epoch  40 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   119.03 |
# | epoch  40 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.57 |
# | epoch  40 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.34 |
# 陋，自依难迟。我取其中必操。若数部，从理而辞，说当十人晚东川南南北立终豹，倾时五个，西背近青械也，进桃壤。山一巾！赫努」写角，一彪绿响，省沌悌夺，权屯身，东陷浮境。之血玻瞒，是病宕极、人，调父建波、程
# | epoch  41 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.36 |
# | epoch  41 |   400/ 1010 batches | lr 0.00 | ms/batch  8.03 | loss  4.86 | ppl   128.57 |
# | epoch  41 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.75 |
# | epoch  41 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.90 |
# | epoch  41 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   116.89 |
# 腐；特不然张郃穷而冲视：“何不难好操父乎？”瑜曰：“公闻共敢出报之，就日要到。”该谓布曰：“是使料主公军何石勤，何敢故预之哭。”孔明双书不扇，然吉罢气，流目率营，身令抢人光于印下去谢曹操，被臣引兵船投
# | epoch  42 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.88 | ppl   132.25 |
# | epoch  42 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.85 | ppl   128.18 |
# | epoch  42 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   118.49 |
# | epoch  42 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   118.01 |
# | epoch  42 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   117.05 |
# 被之平秀为言之，迁者尽起。<eos>追有仁，告入大将：并晙二将。<eos>得休乘赋计，以言曹军之面，搭绝不可。一冲十百余夺，吴军二十姓人，正在调匙。三面齐声，髦霎血疑，忽因得以灰出汉去，篷畋火容由；却休弃徐阳；忽先屯
# | epoch  43 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.89 | ppl   132.89 |
# | epoch  43 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.86 | ppl   128.64 |
# | epoch  43 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.76 |
# | epoch  43 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.90 |
# | epoch  43 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   116.71 |
# 未起之叫。一日，皆然阿郃。廖珪大喜，便领敌人望脱，玄德在首面前。玄德才唤一百余人，按车南阙，猖仿劝替，二人骑厉枪帜号。维引军民正自赌。懿离麾，布遇了昔主王仪、魏延，只至城池，即拿暹起檄，檄刀慰、汉桓送
# | epoch  44 |   200/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.89 | ppl   132.59 |
# | epoch  44 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.86 | ppl   128.45 |
# | epoch  44 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.52 |
# | epoch  44 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.76 |
# | epoch  44 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   116.71 |
# ，后主有其己堂。店爽酣喊土填礼，辞城勒开神庄。射甚船召姜鬓及师重，乃与贾瑜出贺。一夜乘此乃成行，不及死事。曹操见计至，会黄ぁ遣军军伏呼大骂曰：“臣一更长月军拂在不过！”却说责礼，谓云长曰：“逅奏者密盛
# | epoch  45 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.88 | ppl   132.28 |
# | epoch  45 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.85 | ppl   128.10 |
# | epoch  45 |   600/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.77 | ppl   118.46 |
# | epoch  45 |   800/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.77 | ppl   117.53 |
# | epoch  45 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   116.97 |
# 校辞。先孟达正绕一目，急共称衣突，便差袁术班官郏于富漫官军；右时陶镜、褚遂分兵力于成口，直马然大败。关公烧了时。贤驱与孟明提枪而出。着飞合忽然战　孔明，教孙卓下城而败。孔明直各令长进五千兵来。望约金鹿
# | epoch  46 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.48 |
# | epoch  46 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.04 |
# | epoch  46 |   600/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.77 | ppl   118.32 |
# | epoch  46 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.47 |
# | epoch  46 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   117.27 |
# 。乐顷奏刀声声棹，书仰宴而去，上锦面尽腰石，身首刺出其地曰：“今汝先相断其一寇也！此燥则吾，何救法大议。”人事曰：“贤公字乃膝龙大带，主不及岑母之为璋：今周艾、蒋忠挽书你矣。”陶允告曰：“将欲再往仪奏
# | epoch  47 |   200/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.89 | ppl   132.79 |
# | epoch  47 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.85 | ppl   128.10 |
# | epoch  47 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.59 |
# | epoch  47 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.90 |
# | epoch  47 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   116.61 |
# 绶粮僵，伏许都五蔽卧吾骑索京公，外麦王儒，解赴满箭。玄德伏麦江阳，归深为军柩掎，堂水致文下辔，为列江和安柴，嫁海总卧，素力开上军高，自然忠此于，来日来来。”遂报吕操；聚吴兵去亲何后，见那军”，命平忠孝
# | epoch  48 |   200/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.89 | ppl   132.31 |
# | epoch  48 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.85 | ppl   128.31 |
# | epoch  48 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.75 |
# | epoch  48 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.50 |
# | epoch  48 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   117.19 |
# 太席孰旨，三人之罢，征推之意。能情有所疽，星三二半也。乃蹉尧久，字为府，足尽置帅；艨为羊殄之士也；未饮宴食，坐兵劫贵，不能教其埋须。一手皆尔瑜，共以孟霞弟累。”遂使刃持肆、严咬棺，乃荡俄纷“定数事边。
# | epoch  49 |   200/ 1010 batches | lr 0.00 | ms/batch  8.11 | loss  4.89 | ppl   132.64 |
# | epoch  49 |   400/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.85 | ppl   128.09 |
# | epoch  49 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   119.00 |
# | epoch  49 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   118.10 |
# | epoch  49 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   117.30 |
# 之事，何故庞德同？”言曰：“不恐献战条把，必贤子到辎口策之事。”呈报关褚曰：“汝闻伯篇共何皆易兆？”孔明曰：“□客以荷贤快人，若因使后大王匹小，制变和之向山，主身不服，乃此地之仇乎？”玄德曰：“公之正
# | epoch  50 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.88 | ppl   131.85 |
# | epoch  50 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.25 |
# | epoch  50 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.57 |
# | epoch  50 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.83 |
# | epoch  50 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   117.25 |
# 而哭。件庶送沙骨之玺，字人时；女灵飏胪也，实非董曰禧细之霎；是薛恢入西陵，览三事巾向，昶灵但死。数日懿挥车，不可掩规。纯马环地泣出曷烈，不表歌，说当投敌。使夜会基虽服宕。玄德预归忧。马超又出迎不复，使
# | epoch  51 |   200/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.88 | ppl   132.09 |
# | epoch  51 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.85 | ppl   127.76 |
# | epoch  51 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   118.25 |
# | epoch  51 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.59 |
# | epoch  51 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   117.18 |
# 抵带。<eos>郭良据中辈，挂为桥门，一焚金甲，作毒一童。后军，天神尽隐以入盏。司马懿时害得云长，将人远胜：乡鞭有藏王以自。孙权拜叹，曰：“父前公先非应应，何乃欲擒皇谋？”孔明大喜，急责危曰：“此凭关妙，恐大
# | epoch  52 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.89 | ppl   132.43 |
# | epoch  52 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.86 | ppl   128.58 |
# | epoch  52 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.95 |
# | epoch  52 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.92 |
# | epoch  52 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   116.99 |
# 处等中朱恭，涕椁审翼之。<eos>公周获受秀，彼能赏回。”于却说五人至，马獠刺麟惊。玄德曰：“莫防他师已走，则守火下，遂报军降。”冥以汉下，平已感之。<eos>正示帐口。人报：“吾乃不能计故，何且更自致序。时吾傅公为
# | epoch  53 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.72 |
# | epoch  53 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.13 |
# | epoch  53 |   600/ 1010 batches | lr 0.00 | ms/batch  8.22 | loss  4.78 | ppl   118.81 |
# | epoch  53 |   800/ 1010 batches | lr 0.00 | ms/batch  9.10 | loss  4.77 | ppl   117.62 |
# | epoch  53 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.80 | loss  4.76 | ppl   116.99 |
# 佑”于岸上飞轻蒸雨腹，行奢被涪时告姜蒙，渐住宾酒，引兵回精孙卓，到谷中已多，曹火大哭兵杀，得密株斩之矣。蔡乐入肩已忽，听令取寨超，令曹承先日已到，出后十里迎了许都。众将皆令连城。坚让百行招声曰：“金烧
# | epoch  54 |   200/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.89 | ppl   132.71 |
# | epoch  54 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.85 | ppl   128.07 |
# | epoch  54 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.85 |
# | epoch  54 |   800/ 1010 batches | lr 0.00 | ms/batch  8.03 | loss  4.77 | ppl   117.93 |
# | epoch  54 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   116.96 |
# ，亦且与我之细定。欲奔取白阳锐，吾处何人同笑曰：“洛台人指诈话知意助，谁必从我送待之？”遂拔于金勤，领兵。一更下，铁石大路，喊声冲漳，一擐色伏护路内瘦、熙，帝化身废首。超马自手，左右犯于车只之歇。令蒋
# | epoch  55 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.87 |
# | epoch  55 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.86 | ppl   128.61 |
# | epoch  55 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   118.44 |
# | epoch  55 |   800/ 1010 batches | lr 0.00 | ms/batch  8.03 | loss  4.76 | ppl   117.19 |
# | epoch  55 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.42 |
# 壁于西水背阵。党此不聚人也。关公密不数书，皆合历婚火隐宫大起：刘谒乃落人官，字召董浩，屯怀我王去。备军遵为火尉，即移城马成之间，属孔明北共，尽在华奉之烦；助道黄谦不是，我汉子豫被，名告耶？”呈孔明报三
# | epoch  56 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.59 |
# | epoch  56 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.19 |
# | epoch  56 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   118.14 |
# | epoch  56 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.84 |
# | epoch  56 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   116.85 |
# 风百日，以于慈奏之。平献将、周郃元重不相立。壮军己才亡也。安知心下也。部主公乘立失之，誓悉牵刚睁尖而出，张捧引百千马士；投祁鹿路。其人冲曰西官丁，人皆加治，失诏之交。”颍齿于中大曰：“事军原散。儒曰：
# | epoch  57 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.59 |
# | epoch  57 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.85 | ppl   128.21 |
# | epoch  57 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.88 |
# | epoch  57 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.77 |
# | epoch  57 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   116.78 |
# 威为十巡场，成愬，心者不能居附草。但命先主兵聚董亮。献须后主公赏。操曰：“山带南河高韦，商帝当番等，必然烧而一起，何自张和。”<eos>卿奉殉远回于南城，，只欲知用寨脯刑也。孔明登身前兵来攻，至操惊一声，茂兴
# | epoch  58 |   200/ 1010 batches | lr 0.00 | ms/batch  8.03 | loss  4.89 | ppl   132.42 |
# | epoch  58 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.14 |
# | epoch  58 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   119.21 |
# | epoch  58 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.72 |
# | epoch  58 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   117.03 |
# 煮器黑染，攻专黄黄后，乃布将马，莫有霸主。<eos>是胡植、诸儿也，句暮骑全安继解太州１飞见蜀寨军丝釭：一将维，立暗窥封兵去粮之言，戈不成强，刀起印琊。<eos>早至九合，且出。赍教城中百姓；古平妻大惊救探。当蜜张
# | epoch  59 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.89 | ppl   132.29 |
# | epoch  59 |   400/ 1010 batches | lr 0.00 | ms/batch  7.99 | loss  4.85 | ppl   128.06 |
# | epoch  59 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   118.48 |
# | epoch  59 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.56 |
# | epoch  59 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   116.79 |
# ，善立闿形。范申个刀刀，纵上于据见。皓求出其数农，越士为养孙休晋匹有诗。云长三功过尚坡，某乃人言之，雾旆醮，鼻熟春丹。松方曰：“前中仙诸侯常日，高杆一攀，以后二者，在一晔汉北夏侯渊回溪文。旱时去告此，
# | epoch  60 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.72 |
# | epoch  60 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.29 |
# | epoch  60 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.63 |
# | epoch  60 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   118.09 |
# | epoch  60 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   117.20 |
# 快示其气。不八回，阴阳未足书。玄德与刘备四将至　你髀恃手，误俭伺事。簇的赵范立允，操恭如何且毕。丕曰：“兄敬休令，且索艾使，立恁弓地，不至骧王所傅，未听彼堂，吾必速死。<eos>天恼以虎那书，无理死理龟遭胜，
# | epoch  61 |   200/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.89 | ppl   132.47 |
# | epoch  61 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.35 |
# | epoch  61 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.73 |
# | epoch  61 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.65 |
# | epoch  61 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   117.06 |
# 搭半人，以降荆州，邵麦立高，一盲藏藏；灵添名知，僻趷字龙绦许，观见老子而定，左权于金阳天为府。竟有昭郡器临胄犯操赞，勒一剑至一沛舟，剿其职少，问仇必痊，令军士配曰：“此东北，苦语保帝；纡吏姑国善，桎骧
# | epoch  62 |   200/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.89 | ppl   132.73 |
# | epoch  62 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.85 | ppl   128.13 |
# | epoch  62 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   118.35 |
# | epoch  62 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.76 |
# | epoch  62 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.50 |
# 误之计，不渡军，然后皆民断之，低横南其人，缓窜大械，淮在汉桥上箭坂之计，不用献建水。蜀兵、左右撤文放令寨，布寻孽“咬草，次日赶来。却说孟生已信。自入及大妻，怒曰：“若何事？”众夫人至，拜告大声曰：“然
# | epoch  63 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.74 |
# | epoch  63 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.02 |
# | epoch  63 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   118.42 |
# | epoch  63 |   800/ 1010 batches | lr 0.00 | ms/batch  8.08 | loss  4.77 | ppl   117.87 |
# | epoch  63 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.07 | loss  4.76 | ppl   116.61 |
# 楼。数人正留懿问之，备有袁术在轻三兵，孟获可然乡水。”乃糜、邓宫、马班、内后商议，孟都、孙芳于朱嶷之心。孔明曰：“尘野野驯乐，可是不意：如洞病车而屯矣。”司马昭出枪张飞，上刀设宴而倒，坐无不听。荆晚只
# | epoch  64 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.46 |
# | epoch  64 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.85 | ppl   127.94 |
# | epoch  64 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.56 |
# | epoch  64 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.61 |
# | epoch  64 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   116.90 |
# 车，刺带大路。马岱、韩令悦曰：“如此若机耳！”竺曰：“南舟李国马玺，必可欲令，皆渡孔明，家胄急香。”众将大喜，将军师死伏兵。正换韩优曰：“某向汉中有何？”遂船头尺沦，将问流。绍一童叹曰：“融勇命，不能
# | epoch  65 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.89 | ppl   132.91 |
# | epoch  65 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.86 | ppl   128.40 |
# | epoch  65 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.60 |
# | epoch  65 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.53 |
# | epoch  65 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   117.18 |
# 条围而重罢。不知，奋大惊曰：“昨便令魏贼，非作投君。<eos>某等纵付其克，即客察之。”遂拨马停起，马迎了。关公皆披逮问犹书。玄德曰：“诸葛亮相为凡功，安敢不秽。吾宽意之策，必有豫宁致之。丞相非年基卓、拽水，
# | epoch  66 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.55 |
# | epoch  66 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.18 |
# | epoch  66 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.81 |
# | epoch  66 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.64 |
# | epoch  66 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   117.28 |
# 夔之，范不为嵩等。不讨冠西一放，奔转练郡，“高小军马曜周芝，檄—背后降绢，今为诸郡，求后陇驾营，倘此以救后军曲而图；一廉闻于江粮城。二十二岁费仓关，亭“雍钦、甘皇稔土人马。”操曰：“北原必寮此事，然后
# | epoch  67 |   200/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.89 | ppl   132.62 |
# | epoch  67 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.23 |
# | epoch  67 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.99 |
# | epoch  67 |   800/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.77 | ppl   118.00 |
# | epoch  67 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   117.09 |
# 也。”称者，兀拨内光起，大作甲语出，右船退宫，从，皆相整命。操再勒表拦奏。杨仪、司马璋领路前往又战大官，却引数千精兵追在操谷寨中。<eos>忽然一声伞裸，闻者拜池之，祭赏焦灵。诸敬亦拆作诸将润提军，惟是刘封之
# | epoch  68 |   200/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.89 | ppl   132.75 |
# | epoch  68 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.13 |
# | epoch  68 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   118.43 |
# | epoch  68 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.83 |
# | epoch  68 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   117.06 |
# 墉落牛银导。”玄德曰：“吾死云武，以目割玄休，再然如此计，明免作喝否？”云长哭慌急望。孔明喝集蜀兵之词。数人有宴：自还许侯文，益史吕布为荆州，险土韩叉之吏为成大多何人讨恩！”孔明笑。<eos>即唤华家、休知盖
# | epoch  69 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.30 |
# | epoch  69 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.85 | ppl   128.30 |
# | epoch  69 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.94 |
# | epoch  69 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.49 |
# | epoch  69 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   117.13 |
# 说想辟，少至破东，东山不肯言，赚授宁兴后言，猛骑铁青坂食。王望袁氏吴澄孔明，皆为兄平；一月，戮名一众。故攻奏孔明。凌于前上船，使回蛮兵。三下军便袭报杨飞，大骂邓泰。权曰：“此乃孔明，岂不忧胜！”蔡平曰
# | epoch  70 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.53 |
# | epoch  70 |   400/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.85 | ppl   128.05 |
# | epoch  70 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   118.32 |
# | epoch  70 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.82 |
# | epoch  70 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   116.96 |
# 盈，人督粮作；是心挥山而在步。向起拔火埋箭过于南禁车死；某见大军而在。”原至东吴尽战坑缚起，急是鲁嘶使接赶。<eos>曹操大喜，肃报曰：“汝你人师来无相反之？”候退兵虚突，寻以众公也。<eos>看了张翼、姜旺、韩仪、
# | epoch  71 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.79 |
# | epoch  71 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.37 |
# | epoch  71 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.81 |
# | epoch  71 |   800/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.77 | ppl   118.16 |
# | epoch  71 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   117.14 |
# 军轲角札而相。中是是丞相庇为关将皇百，并纲刘备为诸将。星据方隐败曹兵，自当到船。<eos>昭见其知于韩济，乃筵后武之志，斡伐主又马腿在，内落相岸！须得令城水北万入处，心受住胀，不知布，遣孙权各就东痛齐置。<eos>如
# | epoch  72 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.49 |
# | epoch  72 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.86 | ppl   128.52 |
# | epoch  72 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.52 |
# | epoch  72 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.93 |
# | epoch  72 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.00 | loss  4.76 | ppl   117.02 |
# 促不决物，所退可往矣！”维乃引精兵院亲护马。赤丹也，传孔云劫斤，连夜兵之势，拨帐背来，被孔康投西门带马赶心。<eos>维引宴看兵一山，冀州，把三门出心，欲收写开，孙璋观病，唤后人原见一眩喘，临王宁引十六骑，乞
# | epoch  73 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.35 |
# | epoch  73 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.14 |
# | epoch  73 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   118.42 |
# | epoch  73 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.59 |
# | epoch  73 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   116.98 |
# 鞦，拒其廊。二将军吏火起，亡为存贼。”<eos>一大褛问来，杀之未来，使号飞方遍涂疮响，只举濮陵大雨，有襄逊，乱诌应成将，一分一彪两毛校横马，石珠谍诡粮，大哀不追。操竟吴当职兵到。乃提刀、魏中、戕优设敌诏共事
# | epoch  74 |   200/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.89 | ppl   132.58 |
# | epoch  74 |   400/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.85 | ppl   128.35 |
# | epoch  74 |   600/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.78 | ppl   118.60 |
# | epoch  74 |   800/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.77 | ppl   117.46 |
# | epoch  74 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   116.57 |
# 之。可许喃依了尽下中一人旗于蜀都，从开帐上，金红近突天地，时赤弓马，置蜈排吹信，隘阳于中护北淳也。关营大一，带田巢空抢口后。操令夺兵中喘僚，并欲道之卒，是汉亟畿惯龙毛之郡为粮，方必引霸解众士。至仪武军
# | epoch  75 |   200/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.89 | ppl   132.47 |
# | epoch  75 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.86 | ppl   128.51 |
# | epoch  75 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   118.39 |
# | epoch  75 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.72 |
# | epoch  75 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.76 | ppl   116.85 |
# 帝籍女之士，故操挂路相住。忽将夏侯惇必引三四百进双。<eos>却说张鲁欲来投寨外问之，去得川操安助，为命助其泠悌回，不误铠气，是克颀。法诸分一人，乃全听；却闻玄德行风，不深昏鼕，绣且不及害，忽然肃曰：“吾丞相
# | epoch  76 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.70 |
# | epoch  76 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.86 | ppl   128.63 |
# | epoch  76 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.64 |
# | epoch  76 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   117.95 |
# | epoch  76 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.01 | loss  4.76 | ppl   116.79 |
# 斜车，一面，有得魏操而退。”<eos>飞望山山木寿刺大怒，指元乾民加示大惊。布曰：“公乃不答。”订拆曰：“吾愿必杀我好宾谋之计也。命暗可图必休。其人耻如其数天下。”帝曰：“臣孤忿将前也。今先今者为常，憾食不移
# | epoch  77 |   200/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.89 | ppl   132.64 |
# | epoch  77 |   400/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.85 | ppl   128.22 |
# | epoch  77 |   600/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.78 | ppl   118.90 |
# | epoch  77 |   800/ 1010 batches | lr 0.00 | ms/batch  8.02 | loss  4.77 | ppl   118.08 |
# | epoch  77 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.03 | loss  4.76 | ppl   116.97 |
# 别，瑾不念何。玄德尔军恐吾留还二主旧世。”遂入门下，擒曹仁讳已曰：“来如其好周艾所竹教昃之计也。<eos>绍常驴上马五多。不及多生如！”范大喜，闻上风失。只见二将去至。玄德见后使纪遣年宋熙与傍忠陷牛楼陈，拴皆
# | epoch  78 |   200/ 1010 batches | lr 0.00 | ms/batch  8.08 | loss  4.88 | ppl   132.08 |
# | epoch  78 |   400/ 1010 batches | lr 0.00 | ms/batch  8.12 | loss  4.85 | ppl   127.76 |
# | epoch  78 |   600/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.78 | ppl   118.52 |
# | epoch  78 |   800/ 1010 batches | lr 0.00 | ms/batch  8.09 | loss  4.77 | ppl   118.17 |
# | epoch  78 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.76 | ppl   116.93 |
# 被使不膝。专大牲靠心于一望，却命凉中定的来，每将娘鞭一千八千，前阵坐伏。二官已发，教杨馥守鞒安去，在柴秣白水之来。大公怒。又与操不至。孔明拜成而视之。<eos>正是：法濬了大征，因蠹祭首。”即引人随三百骑各出
# | epoch  79 |   200/ 1010 batches | lr 0.00 | ms/batch  8.08 | loss  4.89 | ppl   132.74 |
# | epoch  79 |   400/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.86 | ppl   128.51 |
# | epoch  79 |   600/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.78 | ppl   118.81 |
# | epoch  79 |   800/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.77 | ppl   117.76 |
# | epoch  79 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.76 | ppl   116.85 |
# 上执胆，门边嚷不泣檀之，按本虚道请级。未及是此，问曹真有震之后，乃辛良、典忠一路连州，来搬洛阳，突来攻祸，不得引军寨势常绣任于后中。操当干息。一更敢应。玄德回时簪迎，敢至夜津。策班对汲戟，皆语暗食；次
# | epoch  80 |   200/ 1010 batches | lr 0.00 | ms/batch  8.09 | loss  4.88 | ppl   132.16 |
# | epoch  80 |   400/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.86 | ppl   128.53 |
# | epoch  80 |   600/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.78 | ppl   118.83 |
# | epoch  80 |   800/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.77 | ppl   117.49 |
# | epoch  80 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.76 | ppl   117.00 |
# 大业，蒲虚端于忠耳。卧「锦＝，依方来头。超毕，诸队弃入帐中而入，遂取之项甲，。—嘏将马望江山死而遍久，止城中骤连，回赵昂近城。周璋引操便出入。公闻问曰：“欲伤恁穿人犬，必为副军，当杀将五六人，亦宜下奸
# | epoch  81 |   200/ 1010 batches | lr 0.00 | ms/batch  8.09 | loss  4.89 | ppl   132.73 |
# | epoch  81 |   400/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.86 | ppl   128.48 |
# | epoch  81 |   600/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.78 | ppl   118.69 |
# | epoch  81 |   800/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.76 | ppl   117.24 |
# | epoch  81 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.76 | ppl   116.97 |
# 彼，特嗟天下也，全生元柏也。成、安，请酒驯扇廖嶷。<eos>第岁二十里，都跃凉旄，共邸为蛮，稍获简二书；檄图糜，字高担，幸感百月舌；恸手，韧误帝缳，天水告世；求加众褛者，坡逵人匐。钧日宝慢三多赐命，飞丧而战，
# | epoch  82 |   200/ 1010 batches | lr 0.00 | ms/batch  8.11 | loss  4.88 | ppl   132.25 |
# | epoch  82 |   400/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.85 | ppl   128.24 |
# | epoch  82 |   600/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.78 | ppl   119.04 |
# | epoch  82 |   800/ 1010 batches | lr 0.00 | ms/batch  8.07 | loss  4.77 | ppl   117.80 |
# | epoch  82 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.76 | ppl   117.27 |
# 见名籍，见敬穴麾朝并蒺宠。言其上毒之妖，夕英悔。我便征术捐，围乡贼主。当吴虎陆人俘州无得，扬世为内，勿承熊敌。将张蜜乎？”<eos>统大怒曰：“吾平以内日，虽雪江公一路为为首。因知汝不侵大，恐法与曹仁。”孔明
# | epoch  83 |   200/ 1010 batches | lr 0.00 | ms/batch  8.10 | loss  4.89 | ppl   132.52 |
# | epoch  83 |   400/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.86 | ppl   128.50 |
# | epoch  83 |   600/ 1010 batches | lr 0.00 | ms/batch  8.07 | loss  4.77 | ppl   118.28 |
# | epoch  83 |   800/ 1010 batches | lr 0.00 | ms/batch  8.07 | loss  4.77 | ppl   117.42 |
# | epoch  83 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.76 | ppl   116.83 |
# 陆英王。人施上民，似夏侯兵，杀曰：“此军方摔棹相獠。嵩久无不齿，才地高下，告令空狱一骑，食子帐枕，二百余军远去。周瑜、上会，向盗毁胜，何人椅服？”孔明笑如答，聚诗伏文安靠为琼。<eos>翼有十字锦字。玄德曰：
# | epoch  84 |   200/ 1010 batches | lr 0.00 | ms/batch  8.09 | loss  4.89 | ppl   132.68 |
# | epoch  84 |   400/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.86 | ppl   128.45 |
# | epoch  84 |   600/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.78 | ppl   118.70 |
# | epoch  84 |   800/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.77 | ppl   118.20 |
# | epoch  84 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.76 | ppl   116.99 |
# 天思之，昔面数面爵处习，以出莩计失地，便斩刘表。国兵克倦衰物，下操理感。妒不问之，虢锡黄术，与近敌；十姓大宜，公欲遮弟农，披髯遽大之间，把伤图罪，尚无幸但，可自一蔓。于酬三石尺，全雳羽元飙偷招。”公曰
# | epoch  85 |   200/ 1010 batches | lr 0.00 | ms/batch  8.09 | loss  4.89 | ppl   132.46 |
# | epoch  85 |   400/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.85 | ppl   128.26 |
# | epoch  85 |   600/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.77 | ppl   118.44 |
# | epoch  85 |   800/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.77 | ppl   117.50 |
# | epoch  85 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.76 | ppl   116.57 |
# ！超酹提彼搦之。今操视之，顾之。周备听马前，曹操候发而敌。<eos><eos>第五十四三回，自见孙乾在冀安之下，收新交，见后打后兵下安道。孙策提议回马，书李璋先锋，遣兵不杀。<eos>连番人马将洞军俱立于前北，若一步疑。策惊
# | epoch  86 |   200/ 1010 batches | lr 0.00 | ms/batch  8.08 | loss  4.89 | ppl   132.58 |
# | epoch  86 |   400/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.86 | ppl   128.41 |
# | epoch  86 |   600/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.78 | ppl   118.72 |
# | epoch  86 |   800/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.77 | ppl   117.58 |
# | epoch  86 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.76 | ppl   116.49 |
# 巧中，怀惧以其湄，乃新服旌野殿，厮砍提船抠，不及桥来长宝：谒链甑弓四造霹之哭。当见近桓绣皆力受荆州邓楙，令精兵而上。军士各广亭。众军受天，将暴袁术、梁铜偏人将满点探死韩韦弱女。松谢曰：“不易此死事时，
# | epoch  87 |   200/ 1010 batches | lr 0.00 | ms/batch  8.07 | loss  4.89 | ppl   132.37 |
# | epoch  87 |   400/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.85 | ppl   128.29 |
# | epoch  87 |   600/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.77 | ppl   118.26 |
# | epoch  87 |   800/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.77 | ppl   117.72 |
# | epoch  87 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.76 | ppl   116.85 |
# 承诌机营；非是诸侯龙劣。昔久见<eos>死不定席赏报闻，曰：“卒军两里，述筵高震，在我船来来请城绍。”胪恋不降，策教归一犭癣就。孔明曰：“难在十阵奸怨！今我践祈，彼既不从，魏中二人一人，余溽致之，齐势割守；公
# | epoch  88 |   200/ 1010 batches | lr 0.00 | ms/batch  8.09 | loss  4.89 | ppl   132.45 |
# | epoch  88 |   400/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.85 | ppl   128.24 |
# | epoch  88 |   600/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.78 | ppl   118.74 |
# | epoch  88 |   800/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.77 | ppl   117.98 |
# | epoch  88 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.76 | ppl   116.99 |
# 枪下手，点军望南川，不杀劫探。<eos>皆在马岱，使将桥中急行得被未助。关云昨是张昭三蝉，见其丈稻，贮草水母，相见其上。进叱鹭，Ｎ给一七日流，羽沈喝曰：“云继其惆，早不不归之矣，舅特何相兵可？”维曰：“子龙知
# | epoch  89 |   200/ 1010 batches | lr 0.00 | ms/batch  8.10 | loss  4.89 | ppl   133.04 |
# | epoch  89 |   400/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.85 | ppl   128.14 |
# | epoch  89 |   600/ 1010 batches | lr 0.00 | ms/batch  8.07 | loss  4.78 | ppl   118.82 |
# | epoch  89 |   800/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.77 | ppl   118.26 |
# | epoch  89 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.76 | ppl   117.03 |
# 棹，被军坐既掩弩，折众一人回愆尚相以。旦子简知豺兽，按殿殡一阵猜其此。夤袍景济。君到牲幼办，瑜军马暂小。刘汉来着万文有屏剑帙礼，遂请二人点营，嘶围退而赴。寨不敢到，径到中南，庄上火起。庞德约下者自相能
# | epoch  90 |   200/ 1010 batches | lr 0.00 | ms/batch  8.10 | loss  4.89 | ppl   132.72 |
# | epoch  90 |   400/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.85 | ppl   128.05 |
# | epoch  90 |   600/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.78 | ppl   118.83 |
# | epoch  90 |   800/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.77 | ppl   117.59 |
# | epoch  90 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.76 | ppl   116.95 |
# 酂。这尉逃避，左右将楼，通不金石练铁旗。筑春上门上又轮地，不尚之垂号，火排斯射。钟晚姑后受手草篙，急如前会，因天客赏甘松来，供神灵坛，看凶其市门，乃眷祀其，再作出旦曰黄渊去，仗红鼎甲，一声喊响，人士皆
# | epoch  91 |   200/ 1010 batches | lr 0.00 | ms/batch  8.09 | loss  4.89 | ppl   132.66 |
# | epoch  91 |   400/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.85 | ppl   128.21 |
# | epoch  91 |   600/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.77 | ppl   118.45 |
# | epoch  91 |   800/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.77 | ppl   117.99 |
# | epoch  91 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.76 | ppl   117.02 |
# 之为人，实其藤令。营提侵，至揪草忍。王中、潘充士列曰：“母蒋忠来行，何在取此也！”不想孔融保程泰于马前蛮仁谏。邓虔大骂，“云：“誓来二年，军马不意，如何言我耶？”近都立下乘车上看见曹操，乃谓首县一枪铜
# | epoch  92 |   200/ 1010 batches | lr 0.00 | ms/batch  8.09 | loss  4.89 | ppl   132.54 |
# | epoch  92 |   400/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.85 | ppl   128.08 |
# | epoch  92 |   600/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.78 | ppl   118.67 |
# | epoch  92 |   800/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.77 | ppl   117.67 |
# | epoch  92 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.11 | loss  4.76 | ppl   116.90 |
# 狮，襄擂厉庑；乃是老子粮由算一畅，禁仰寿肘。忽至一乐、天，渊，使侯藏大有醉于泉中。喝下董醒曰：“公乃迈善哀于此度。”<eos>庶曰：“公都主公休去。”孔明曰：“后等人报何处？”操秋辟即命失毕，拔剑上书。叙大怒
# | epoch  93 |   200/ 1010 batches | lr 0.00 | ms/batch  8.08 | loss  4.88 | ppl   132.26 |
# | epoch  93 |   400/ 1010 batches | lr 0.00 | ms/batch  8.10 | loss  4.85 | ppl   128.07 |
# | epoch  93 |   600/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.78 | ppl   118.58 |
# | epoch  93 |   800/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.77 | ppl   117.58 |
# | epoch  93 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.76 | ppl   116.68 |
# ？真求以死张辽杀良祖子翱，不甚无言，不非一人檄》。诸葛亮扶多暗挂，然努指吞不见，以从其异。不得此更，勿敢及问。众面b旨士视事，权登悬羕肱，愤承霹旌，取及于地辛地。馨教陈途而回。玄德问：“有何？”马谡传
# | epoch  94 |   200/ 1010 batches | lr 0.00 | ms/batch  8.09 | loss  4.89 | ppl   132.38 |
# | epoch  94 |   400/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.85 | ppl   128.24 |
# | epoch  94 |   600/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.78 | ppl   119.10 |
# | epoch  94 |   800/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.77 | ppl   117.79 |
# | epoch  94 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.76 | ppl   117.06 |
# ，彭丹伍，不开出中锋，乃有不归，还治武安人，报是丞相诣寰之，司马昭入帐痛贼，留刘皇外引而退。正是夜中张郃乱起，袍酗金白俟巾；急于一千军箭甲火声，刀辆昧掩，伤岸插无二野之战。孔明答于合下，率兵出大路，八
# | epoch  95 |   200/ 1010 batches | lr 0.00 | ms/batch  8.08 | loss  4.89 | ppl   132.74 |
# | epoch  95 |   400/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.85 | ppl   128.34 |
# | epoch  95 |   600/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.78 | ppl   118.86 |
# | epoch  95 |   800/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.77 | ppl   117.76 |
# | epoch  95 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.77 | ppl   117.44 |
# 余计。随诏大王，观荆州呆而下，虔如吾获，皆准君。<eos>当日作闻明，乃与大军、张辽复至河寨！看知全命，却说关长玲营来来，却彼领兵归后大散。正约魏延正往荆襄而江；幡内八半，尽跃可进，内地相赴。云长领军奔取秦策
# | epoch  96 |   200/ 1010 batches | lr 0.00 | ms/batch  8.10 | loss  4.89 | ppl   132.88 |
# | epoch  96 |   400/ 1010 batches | lr 0.00 | ms/batch  8.08 | loss  4.85 | ppl   128.13 |
# | epoch  96 |   600/ 1010 batches | lr 0.00 | ms/batch  8.07 | loss  4.78 | ppl   118.73 |
# | epoch  96 |   800/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.77 | ppl   117.86 |
# | epoch  96 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.76 | ppl   116.95 |
# 翰烝傍陵北。于望为弃之，许弟会处擂身不勇，数日山劳。<eos>云长就欲先踏也。须观，再不过；云长进在在宗庶，随此不能辞读。楙拜作内相侍，手措苦为，瑶剑闭乱，皆回女太守使王，操与刘达宁事、高常救慰。张淮奏曰：“
# | epoch  97 |   200/ 1010 batches | lr 0.00 | ms/batch  8.10 | loss  4.89 | ppl   132.35 |
# | epoch  97 |   400/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.86 | ppl   128.69 |
# | epoch  97 |   600/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.78 | ppl   118.52 |
# | epoch  97 |   800/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.77 | ppl   117.73 |
# | epoch  97 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.76 | ppl   117.29 |
# ，而来以亲也。”流个大喜，乃曰：“今但取，不如何超耶？”玄德曰：“邓坚杀回，由投洛陵，丞相归之。”令岸又歌怒，无痊辎伐，正乃吴国同星丹甲栎，昏代吕布幸觉矣。关公奏弃，乃关公丞相遣仁弟，自守应寨。两平妻
# | epoch  98 |   200/ 1010 batches | lr 0.00 | ms/batch  8.09 | loss  4.88 | ppl   132.12 |
# | epoch  98 |   400/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.85 | ppl   127.93 |
# | epoch  98 |   600/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.78 | ppl   118.67 |
# | epoch  98 |   800/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.77 | ppl   117.45 |
# | epoch  98 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.06 | loss  4.76 | ppl   116.92 |
# 令将军分住；汝必来断，彼闻必归军士璆深发。就见鲁权窗锐羌洞者城去：运鹤远处。<eos>儒与御内俱下一军上环令而从。又将船去投荆州与都引兵到，凌德羌主拆于荆州，骁半抬手弓持一齐，不敢杀疑。那部抄埋起起，急飞乘枪
# | epoch  99 |   200/ 1010 batches | lr 0.00 | ms/batch  8.09 | loss  4.89 | ppl   132.32 |
# | epoch  99 |   400/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.85 | ppl   128.33 |
# | epoch  99 |   600/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.78 | ppl   118.86 |
# | epoch  99 |   800/ 1010 batches | lr 0.00 | ms/batch  8.05 | loss  4.77 | ppl   117.95 |
# | epoch  99 |  1000/ 1010 batches | lr 0.00 | ms/batch  8.04 | loss  4.76 | ppl   116.92 |
# 求还民寨去了。忽因一方日待问，未相不逃公，不总。张郃有之时方毕，尘扇益弩三镜道，砍新占华。宁勿久，大喜，鹪引鼓甲，斩于孟获，如何得之。其面可搦防之。愿有神人，汝山摆江。操与结命密谋来得，事何如问：刘自
